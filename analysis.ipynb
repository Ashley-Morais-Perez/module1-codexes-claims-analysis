# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashley-Morais-Perez/module1-codexes-claims-analysis/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/cf87867a-c878-4709-84f4-29be1b07ae5b/hha.csv')

# %%
df
# Out:
#      BENE_ID|CLM_ID|NCH_NEAR_LINE_REC_IDENT_CD|NCH_CLM_TYPE_CD|CLM_FROM_DT|CLM_THRU_DT|NCH_WKLY_PROC_DT|FI_CLM_PROC_DT|PRVDR_NUM|CLM_FAC_TYPE_CD|CLM_SRVC_CLSFCTN_TYPE_CD|CLM_FREQ_CD|FI_NUM|CLM_MDCR_NON_PMT_RSN_CD|CLM_PMT_AMT|NCH_PRMRY_PYR_CLM_PD_AMT|NCH_PRMRY_PYR_CD|PRVDR_STATE_CD|ORG_NPI_NUM|AT_PHYSN_UPIN|AT_PHYSN_NPI|PTNT_DSCHRG_STUS_CD|CLM_PPS_IND_CD|CLM_TOT_CHRG_AMT|PRNCPAL_DGNS_CD|ICD_DGNS_CD1|ICD_DGNS_CD2|ICD_DGNS_CD3|ICD_DGNS_CD4|ICD_DGNS_CD5|ICD_DGNS_CD6|ICD_DGNS_CD7|ICD_DGNS_CD8|ICD_DGNS_CD9|ICD_DGNS_CD10|ICD_DGNS_CD11|ICD_DGNS_CD12|ICD_DGNS_CD13|ICD_DGNS_CD14|ICD_DGNS_CD15|ICD_DGNS_CD16|ICD_DGNS_CD17|ICD_DGNS_CD18|ICD_DGNS_CD19|ICD_DGNS_CD20|ICD_DGNS_CD21|ICD_DGNS_CD22|ICD_DGNS_CD23|ICD_DGNS_CD24|ICD_DGNS_CD25|FST_DGNS_E_CD|ICD_DGNS_E_CD1|ICD_DGNS_E_CD2|ICD_DGNS_E_CD3|ICD_DGNS_E_CD4|ICD_DGNS_E_CD5|ICD_DGNS_E_CD6|ICD_DGNS_E_CD7|ICD_DGNS_E_CD8|ICD_DGNS_E_CD9|ICD_DGNS_E_CD10|ICD_DGNS_E_CD11|ICD_DGNS_E_CD12|CLM_HHA_LUPA_IND_CD|CLM_HHA_RFRL_CD|CLM_HHA_TOT_VISIT_CNT|CLM_ADMSN_DT|
# ...

# %%
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/cf87867a-c878-4709-84f4-29be1b07ae5b/hha.csv', sep="|")

# %%
df
# Out:
#              BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 0    -10000010254850 -10000930044285                          W
# 1    -10000010254850 -10000930044285                          W
# 2    -10000010254850 -10000930044285                          W
# 3    -10000010254850 -10000930044285                          W
# 4    -10000010254850 -10000930044285                          W
# ...              ...             ...                        ...
# 6210 -10000010287978 -10000931484035                          U
# 6211 -10000010287978 -10000931484035                          U
# 6212 -10000010287978 -10000931484035                          U
# 6213 -10000010287978 -10000931484035                          U
# 6214 -10000010287978 -10000931484035                          U
#
#       NCH_CLM_TYPE_CD  CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  \
# 0                  10  14-Oct-2021  09-Nov-2021      12-Nov-2021
# ...

# %%
#random sample
df.sample(15)
# Out:
#              BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 3205 -10000010272099 -10000930810140                          W
# 5068 -10000010282130 -10000931250044                          U
# 2324 -10000010267995 -10000930629412                          W
# 4638 -10000010279363 -10000931151761                          V
# 1933 -10000010265806 -10000930534635                          W
# 5297 -10000010283097 -10000931291179                          U
# 4479 -10000010278453 -10000931120988                          U
# 5695 -10000010285118 -10000931379028                          V
# 5    -10000010254850 -10000930044285                          W
# 1067 -10000010260728 -10000930307481                          U
# 5761 -10000010285526 -10000931389071                          W
# 3370 -10000010273028 -10000930853793                          V
# 3978 -10000010276204 -10000931010437                          V
# 1305 -10000010262226 -10000930376422                          W
# ...

# %%
#column names
df.columns
# Out:
# Index(['BENE_ID', 'CLM_ID', 'NCH_NEAR_LINE_REC_IDENT_CD', 'NCH_CLM_TYPE_CD',
#        'CLM_FROM_DT', 'CLM_THRU_DT', 'NCH_WKLY_PROC_DT', 'FI_CLM_PROC_DT',
#        'PRVDR_NUM', 'CLM_FAC_TYPE_CD', 'CLM_SRVC_CLSFCTN_TYPE_CD',
#        'CLM_FREQ_CD', 'FI_NUM', 'CLM_MDCR_NON_PMT_RSN_CD', 'CLM_PMT_AMT',
#        'NCH_PRMRY_PYR_CLM_PD_AMT', 'NCH_PRMRY_PYR_CD', 'PRVDR_STATE_CD',
#        'ORG_NPI_NUM', 'AT_PHYSN_UPIN', 'AT_PHYSN_NPI', 'PTNT_DSCHRG_STUS_CD',
#        'CLM_PPS_IND_CD', 'CLM_TOT_CHRG_AMT', 'PRNCPAL_DGNS_CD', 'ICD_DGNS_CD1',
#        'ICD_DGNS_CD2', 'ICD_DGNS_CD3', 'ICD_DGNS_CD4', 'ICD_DGNS_CD5',
#        'ICD_DGNS_CD6', 'ICD_DGNS_CD7', 'ICD_DGNS_CD8', 'ICD_DGNS_CD9',
#        'ICD_DGNS_CD10', 'ICD_DGNS_CD11', 'ICD_DGNS_CD12', 'ICD_DGNS_CD13',
#        'ICD_DGNS_CD14', 'ICD_DGNS_CD15', 'ICD_DGNS_CD16', 'ICD_DGNS_CD17',
#        'ICD_DGNS_CD18', 'ICD_DGNS_CD19', 'ICD_DGNS_CD20', 'ICD_DGNS_CD21',
#        'ICD_DGNS_CD22', 'ICD_DGNS_CD23', 'ICD_DGNS_CD24', 'ICD_DGNS_CD25',
# ...

# %%
#clean columns format
for column in df.columns:
  print(column)
# Out:
# BENE_ID
# CLM_ID
# NCH_NEAR_LINE_REC_IDENT_CD
# NCH_CLM_TYPE_CD
# CLM_FROM_DT
# CLM_THRU_DT
# NCH_WKLY_PROC_DT
# FI_CLM_PROC_DT
# PRVDR_NUM
# CLM_FAC_TYPE_CD
# CLM_SRVC_CLSFCTN_TYPE_CD
# CLM_FREQ_CD
# FI_NUM
# CLM_MDCR_NON_PMT_RSN_CD
# CLM_PMT_AMT
# NCH_PRMRY_PYR_CLM_PD_AMT
# NCH_PRMRY_PYR_CD
# PRVDR_STATE_CD
# ORG_NPI_NUM
# AT_PHYSN_UPIN
# AT_PHYSN_NPI
# PTNT_DSCHRG_STUS_CD
# CLM_PPS_IND_CD
# CLM_TOT_CHRG_AMT
# PRNCPAL_DGNS_CD
# ICD_DGNS_CD1
# ICD_DGNS_CD2
# ICD_DGNS_CD3
# ICD_DGNS_CD4
# ICD_DGNS_CD5
# ICD_DGNS_CD6
# ICD_DGNS_CD7
# ICD_DGNS_CD8
# ICD_DGNS_CD9
# ICD_DGNS_CD10
# ICD_DGNS_CD11
# ICD_DGNS_CD12
# ICD_DGNS_CD13
# ICD_DGNS_CD14
# ICD_DGNS_CD15
# ICD_DGNS_CD16
# ICD_DGNS_CD17
# ICD_DGNS_CD18
# ICD_DGNS_CD19
# ICD_DGNS_CD20
# ICD_DGNS_CD21
# ICD_DGNS_CD22
# ICD_DGNS_CD23
# ICD_DGNS_CD24
# ICD_DGNS_CD25
# FST_DGNS_E_CD
# ICD_DGNS_E_CD1
# ICD_DGNS_E_CD2
# ICD_DGNS_E_CD3
# ICD_DGNS_E_CD4
# ICD_DGNS_E_CD5
# ICD_DGNS_E_CD6
# ICD_DGNS_E_CD7
# ICD_DGNS_E_CD8
# ICD_DGNS_E_CD9
# ...

# %%
#First Column
df.PRNCPAL_DGNS_CD
# Out:
# 0       Z733
# 1       Z733
# 2       Z733
# 3       Z733
# 4       Z733
#         ...
# 6210    Z733
# 6211    Z733
# 6212    Z733
# 6213    Z733
# 6214    Z733
# Name: PRNCPAL_DGNS_CD, Length: 6215, dtype: object

# %%
count = df.PRNCPAL_DGNS_CD.unique()
len(count)
# Out:
# 64

# %%
df['PRNCPAL_DGNS_CD'].value_counts()
# Out:
# PRNCPAL_DGNS_CD
# Z733      2001
# Z608      1066
# T7432X     630
# Z604       407
# R931       224
#           ...
# Z98890       7
# K011         7
# J029         4
# I0981        3
# T7431X       2
# Name: count, Length: 64, dtype: int64

# %%
#Second column
df.ICD_DGNS_CD10
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 6210    G43719
# 6211    G43719
# 6212    G43719
# 6213    G43719
# 6214    G43719
# Name: ICD_DGNS_CD10, Length: 6215, dtype: object

# %%
count = df.ICD_DGNS_CD10.unique()
len(count)
# Out:
# 71

# %%
df['ICD_DGNS_CD10'].value_counts()
# Out:
# ICD_DGNS_CD10
# R7303    474
# E669     433
# D649     336
# E8881    331
# I10      217
#         ...
# P90       10
# M797      10
# P369      10
# Y0704      8
# E0922      7
# Name: count, Length: 70, dtype: int64

# %%
#Third Column
df.ICD_DGNS_CD5
# Out:
# 0       E669
# 1       E669
# 2       E669
# 3       E669
# 4       E669
#         ...
# 6210    N181
# 6211    N181
# 6212    N181
# 6213    N181
# 6214    N181
# Name: ICD_DGNS_CD5, Length: 6215, dtype: object

# %%
count = df.ICD_DGNS_CD5.unique()
len(count)
# Out:
# 81

# %%
df['ICD_DGNS_CD5'].value_counts()
# Out:
# ICD_DGNS_CD5
# R931      599
# I259      417
# E8881     328
# E785      321
# E669      282
#          ...
# E11311     11
# I25700      9
# T7411X      8
# G309        5
# Z7682       3
# Name: count, Length: 80, dtype: int64

# %%
#Fourth Column
df.ICD_DGNS_CD14
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 6210    E8881
# 6211    E8881
# 6212    E8881
# 6213    E8881
# 6214    E8881
# Name: ICD_DGNS_CD14, Length: 6215, dtype: object

# %%
count = df.ICD_DGNS_CD14.unique()
len(count)
# Out:
# 55

# %%
#Attempt at Removing NaN from the Unique Count
df = df.ICD_DGNS_CD14
print (df)
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 6210    E8881
# 6211    E8881
# 6212    E8881
# 6213    E8881
# 6214    E8881
# Name: ICD_DGNS_CD14, Length: 6215, dtype: object

# %%
#Attempt at Removing NaN from the Unique Count
df = df.dropna()
print(df)
# Out:
# 37       D649
# 38       D649
# 39       D649
# 40       D649
# 41       D649
#         ...
# 6210    E8881
# 6211    E8881
# 6212    E8881
# 6213    E8881
# 6214    E8881
# Name: ICD_DGNS_CD14, Length: 2382, dtype: object

# %%
count = df.unique()
len(count)
# Out:
# 54

# %%
df['ICD_DGNS_CD14'].value_counts()
# Out:
# ICD_DGNS_CD14
# E669       251
# R7303      158
# D649       143
# E8881      142
# E119       109
# I259       104
# J329       102
# Z653        82
# E781        81
# E1121       80
# I10         79
# P292        72
# Z591        69
# E785        68
# Z9049       55
# Z560        45
# O00109      43
# G479        39
# R4689       37
# I1310       37
# G43719      35
# O039        35
# K37         33
# N181        31
# R52         28
# Z5989       25
# E11319      24
# E1144       23
# Z558        22
# K011        19
# M179        18
# M19049      18
# Z7289       18
# R931        18
# R809        17
# R739        17
# Q870        17
# Z6841       16
# I151        15
# Y0704       15
# R801        15
# Z5982       15
# M810        14
# Z8669       14
# K3532       14
# P7883       13
# Z7689       12
# N1830        9
# Z951         8
# E1022        8
# E1122        7
# E1149        6
# T50901A      5
# E0922        2
# Name: count, dtype: int64

# %%
#Fifth Column
df.ICD_DGNS_CD2
# Out:
# 0       M179
# 1       M179
# 2       M179
# 3       M179
# 4       M179
#         ...
# 6210    Z604
# 6211    Z604
# 6212    Z604
# 6213    Z604
# 6214    Z604
# Name: ICD_DGNS_CD2, Length: 6215, dtype: object

# %%
count = df.ICD_DGNS_CD2.unique()
len(count)
# Out:
# 76

# %%
df['ICD_DGNS_CD2'].value_counts()
# Out:
# ICD_DGNS_CD2
# Z733      1018
# Z608       861
# R931       447
# T7432X     421
# Z604       406
#           ...
# I151         9
# D649         9
# P369         9
# I351         7
# R7303        5
# Name: count, Length: 76, dtype: int64

# %%
#Sixth Column
df.ICD_DGNS_CD19
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 6210    R4689
# 6211    R4689
# 6212    R4689
# 6213    R4689
# 6214    R4689
# Name: ICD_DGNS_CD19, Length: 6215, dtype: object

# %%
count = df.ICD_DGNS_CD19.unique()
len(count)
# Out:
# 32

# %%
df['ICD_DGNS_CD19'].value_counts()
# Out:
# ICD_DGNS_CD19
# D649      162
# R7303     102
# Z558       81
# E669       72
# J329       45
# Z591       41
# R4689      40
# G40909     37
# Z653       24
# P292       23
# E1121      23
# Z5989      22
# E785       20
# T7421X     17
# Z9049      17
# M179       16
# E781       16
# I10        16
# E8881      16
# Z9189      15
# O039       14
# K219       13
# O00109     12
# I259       12
# R52        12
# E1140      12
# E11610     11
# P90         9
# E119        8
# Z608        7
# G43719      6
# Name: count, dtype: int64

# %%
#Seventh Column
df.HCPCS_CD
# Out:
# 0       99238
# 1       99497
# 2       G0129
# 3       G0151
# 4       G0152
#         ...
# 6210    Q5001
# 6211    S9122
# 6212    S9129
# 6213    S9131
# 6214      NaN
# Name: HCPCS_CD, Length: 6215, dtype: object

# %%
count = df.HCPCS_CD.unique()
len(count)
# Out:
# 22

# %%
df['HCPCS_CD'].value_counts()
# Out:
# HCPCS_CD
# 99238    454
# H2000    451
# G0402    451
# 99497    451
# S9131    368
# G0157    362
# G0155    355
# G0151    349
# G0300    339
# Q5001    336
# G0299    334
# G0154    321
# G0153    192
# G0156    161
# T1021    146
# S9122    140
# G0129    137
# G0158    131
# S9129    126
# G0152    117
# G0102      1
# Name: count, dtype: int64

# %%
#Eigth Column
df.ICD_DGNS_CD8
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 6210    R52
# 6211    R52
# 6212    R52
# 6213    R52
# 6214    R52
# Name: ICD_DGNS_CD8, Length: 6215, dtype: object

# %%
count = df.ICD_DGNS_CD8.unique()
len(count)
# Out:
# 77

# %%
df['ICD_DGNS_CD8'].value_counts()
# Out:
# ICD_DGNS_CD8
# E669      442
# D649      430
# R7303     414
# I259      253
# Z653      241
#          ...
# E0922      12
# E1122      10
# E1142      10
# T7431X      7
# N182        6
# Name: count, Length: 76, dtype: int64
